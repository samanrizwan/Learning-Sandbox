# %%
name=input("Enter your name")
print("hi",name)
# Out:
# hi saman

# %% [markdown]
# Python Variables

# %%
x= 2345+4567
print(x)
type(x)

x=" This is a string" #doesnt matter you use single quote r double
y='This is also a string'
print(x,y)

#list is created using square brackets[]
#List items are ordered, changeable, and allow duplicate values.the first item has index [0].

a=[1,2,3,4] 
print(type(a))

fruits = ["apple", "banana", "cherry"]  
print(fruits)
print(len(fruits))
# Out:
# 6912
#  This is a string This is also a string
# <class 'list'>
# ['apple', 'banana', 'cherry']
# 3

# %%
#Tuple is an ordered and unchangeable datatype written with round brackets. first index item is [0]

tuple1 = ("abc", 34, True, 40, "male") 
#the items can be of any data type
print(tuple1[1])
# Out:
# 34

# %%
#A set is a collection which is unordered, unchangeable, and unindexed. 

thisset = {"apple", "banana", "cherry", True, 1, 2} #Duplicate values will be ignored. true and 1 are considered same 

print(thisset)

thisset = {"apple", "banana", "cherry", False, True, 0} #False and 0 is considered the same value:

print(thisset)

set1 = {"abc", 34, True, 40, "male"} #can contain different data types
print(type(set1))

thisset = set(("apple", "banana", "cherry")) # set constructor. note the double round-brackets
print(thisset)

#You cannot access items in a set by referring to an index or a key.

#But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.

thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# {True, 2, 'cherry', 'apple', 'banana'}
# {False, True, 'cherry', 'apple', 'banana'}
# <class 'set'>
# {'cherry', 'apple', 'banana'}
# cherry
# apple
# banana

# %%
#A dictionary is a collection which is ordered,changable and do not allow duplicates. written with curly brackets, and have keys and values.
 #You can access the items of a dictionary by referring to its key name, inside square brackets

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,          #duplicates will overwrite
  "year": 2020
}
print(thisdict)
print(len(thisdict))

#other ways to access items 
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict.get("year")) #get method

keys = thisdict.keys() #will print keys
print(keys)

values = thisdict.values() #will print values
print(values)


car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

y = car.values()

print(y)

car["color"] = "white"

print(x) #after the change
print(y)

i = car.items()  #return each item in a dictionary, as tuples in a list
print(i)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}
# 3
# 1964
# dict_keys(['brand', 'model', 'year'])
# dict_values(['Ford', 'Mustang', 1964])
# dict_keys(['brand', 'model', 'year'])
# dict_values(['Ford', 'Mustang', 1964])
# dict_keys(['brand', 'model', 'year', 'color'])
# dict_values(['Ford', 'Mustang', 1964, 'white'])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'white')])

# %%
#python if elif else.. 

a = 200
b = 33
if b > a:
  print("b is greater than a")  #indention before print is a must
elif a == b:
    print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
#while loop
i = 1
while i < 6:   #run while condition is true
  print(i)
  if i == 3:
    break     # stop the loop even if the while condition is true
  i += 1
# Out:
# 1
# 2
# 3

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#A function is a block of code which only runs when it is called.You can pass data, known as parameters, into a function.A function can return data as a result

def my_function(fname, lname):  #fname and lname are function parameters
  print(fname + " " + lname)

my_function("Emil", "Refsnes")   #emil refsenses are function arguments. parameters and arguments are basically sme thing 
                                    #only difference is arguments are values passed to function and parameters are variables


#You can also send arguments with the key = value syntax. This way the order of the arguments does not matter.

def my_function(child3, child2, child1):
  print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")

#If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#this is called arbitrary argument

def my_function(*kids):
  print("The youngest child is " , kids[1])

my_function("Emil", "Tobias", "Linus")

#Arbitrary Keyword Arguments, use ** ,function will receive a dictionary of arguments, and can access the items accordingly
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# Emil Refsnes
# The youngest child is Linus
# The youngest child is  Tobias
# His last name is Refsnes

# %% [markdown]
# # Class
# A Class is like an object constructor, or a "blueprint" for creating objects. an object has properties and methods python is an oop language Almost everything in Python is an object
#
# All classes have a built in function called init(), which is always executed when the class is being initiated.Use the init() function to assign values to object properties, or other operations that are necessary to do when the object is being created.
#
# The self parameter is a reference to the current instance of the class, and is used to access variables that belong to the class.
#
# It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any function in the class

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name}({self.age})"

  def myfunc(self):                           #class method
    print("Hello my name is " + self.name)

p1 = Person("John", 36)

print(p1)
# Out:
# John(36)
